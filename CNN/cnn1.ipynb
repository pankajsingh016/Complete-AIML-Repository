# %%
from PIL import Image
def convert_webp_to_jpg(webp_path, jpg_path):
    """
    Converts a WebP image to JPG format.

    Args:
        webp_path: Path to the input WebP file.
        jpg_path: Path to save the output JPG file.
    """
    try:
        image = Image.open(webp_path).convert('RGB')
        image.save(jpg_path, 'jpeg')
        print(f"Successfully converted {webp_path} to {jpg_path}")
    except FileNotFoundError:
        print(f"Error: File not found: {webp_path}")
    except Exception as e:
        print(f"An error occurred: {e}")

# Example usage
webp_file = 'london.webp'
jpg_file = 'london.jpg'
convert_webp_to_jpg(webp_file, jpg_file)
# Out:
# Successfully converted london.webp to london.jpg

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
# %matplotlib inline

# %%
image = cv2.imread("london.jpg")

# %%
plt.imshow(image) 
# cv2 read the image in bgr format and plt will directly show the image in rgb format the result will look like

# %%
image = mpimg.imread('london.jpg')
plt.imshow(image)

# %%
r = image[:,:,0]
g = image[:,:,1]
b = image[:,:,2]

f, (ax1, ax2, ax3) = plt.subplots(1,3,figsize=(20,10))
ax1.set_title('R channel')
ax1.imshow(r)

ax2.set_title('G channel')
ax2.imshow(g)

ax3.set_title('B channel')
ax3.imshow(b)

# %% [markdown]
# #### Focus on Filters

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg 

import cv2
import numpy as np

# %matplotlib inline 

image = mpimg.imread('london.jpg')
plt.imshow(image)

# %%
## Convert the image to gray scale 
gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
plt.imshow(gray,cmap='gray')

# %%
gray
# Out:
# array([[201, 202, 203, ..., 203, 204, 205],
#        [200, 201, 202, ..., 203, 204, 204],
#        [199, 200, 201, ..., 202, 203, 203],
#        ...,
#        [175, 171, 179, ...,  83,  84,  88],
#        [175, 170, 177, ...,  90,  91,  96],
#        [175, 169, 175, ...,  94,  94,  98]], dtype=uint8)

# %%
sobel_y = np.array([[-1,-2,-1],[0,0,0],[1,2,1]]) #vertical edge detection
sobel_x = np.array([[-1,0,1],[-2,0,2],[-1,0,1]]) #horizontal edge detection

filtered_image1 = cv2.filter2D(gray,-1,sobel_x)
filtered_image2 = cv2.filter2D(gray,-1,sobel_y)

f, ax = plt.subplots(1,2,figsize=(15,4))
ax[0].set_title('horizontal edge detection')
ax[0].imshow(filtered_image1,cmap='gray')
ax[1].set_title('vertical edge detection')
ax[1].imshow(filtered_image2,cmap='gray')
