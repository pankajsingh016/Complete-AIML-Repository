# %% [markdown]
# ### Day 2

# %%
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

from numpy.random import randn, randint, uniform, sample

# %% [markdown]
# ### Line Plot
# - Time series
# - Single Discrete Variable: Bar Plot,Pie Plot
# - Single continious variable: Histogram
# -

# %%
x = [1,2,3,4,5,6,7,8,9]
y1 = [1,3,5,3,1,3,5,3,1]
y2 = [2,4,6,4,2,4,6,4,2]
plt.plot(x,y1,label="Line L")
plt.plot(x,y2,label="Line H")
plt.plot()

plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title("Line Graph Example")
plt.legend()
plt.show()

# %% [markdown]
# ### Bar Chart

# %%
## Bar Plot

x = [2,8,10]
y = [11,16,9]

x2 = [3,9,11]
y2 = [6,15,7]
plt.bar(x,y,label='x-y variation')
plt.bar(x2,y2,color='g', label='x2-y2 variation')
plt.title("Bar Graph",color='green')
plt.ylabel('y-axis')
plt.xlabel('x-axis')
plt.legend()
plt.show()
# rectangular bars are called as bins.
# plt.barh() do the same thing horizontally

# %%
x1 = [1,3,4,5,6,7,9]
y1 = [4,7,2,4,7,8,3]

x2 = [2,4,6,8,10]
y2 = [5,6,2,6,2]

plt.bar(x1,y1,label="Blue Bar",color='b')
plt.bar(x2,y2,label="Green Bar",color='g')
plt.legend()
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()

# %% [markdown]
# ### Histogram
# - Histogram are just a density plots
# - No. of observation fall in a particular range

# %%
a = np.array([22,59,34,87,23,12,31,22,11,44,53,343,2,34,343,234,43,343])
plt.hist(a)
plt.title("Histogram")
plt.show()

# %%
iris = sns.load_dataset('iris')
iris.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.tail(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
iris['sepal_width'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot.hist()  ## iris.plot(kind ='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind='hist',stacked=False,bins=150)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind='hist',stacked=True,bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris['sepal_width'].diff().plot(kind='hist',stacked=True,bins=30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris['sepal_width']
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
iris['sepal_width'].diff()
# Out:
# 0      NaN
# 1     -0.5
# 2      0.2
# 3     -0.1
# 4      0.5
#       ...
# 145   -0.3
# 146   -0.5
# 147    0.5
# 148    0.4
# 149   -0.4
# Name: sepal_width, Length: 150, dtype: float64

# %%
df = iris.drop(['species'],axis=1)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df.hist(color='orange',figsize=(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %% [markdown]
# ### Pie Chart

# %%
# Data to plot
labels = 'Python','C++','Ruby','Java'
sizes = [215,130,245,210]
colors = ['gold','yellow','lightcoral','lightskyblue']
explode = (0,0,0,0)

plt.pie(sizes,explode=explode,labels=labels,colors=colors,
autopct='%1.2f%%',shadow=False)
plt.axis('equal')
plt.show()

# %%
series = pd.Series([0.2]*5)
series
# Out:
# 0    0.2
# 1    0.2
# 2    0.2
# 3    0.2
# 4    0.2
# dtype: float64

# %%
df.plot.scatter(x='sepal_length',y='petal_length')
plt.show()

# %%
df.plot.scatter(x='sepal_length',y='petal_length',c='sepal_width')
plt.show()

# %%
df2 = pd.DataFrame(randn(10,4),columns=['a','b','c','d'])

# %%
df2
# Out:
#           a         b         c         d
# 0 -0.915081 -1.472934 -1.240811 -0.149311
# 1 -1.329281  0.174297 -0.496336 -0.487644
# 2  0.468793 -0.251195  0.324395 -0.910694
# 3  0.511636 -0.424608 -0.398613 -1.942166
# 4  0.070273 -0.589948  1.050760 -0.877970
# 5  0.047168  0.492349  0.646556  2.368292
# 6  1.674089 -0.225625  0.543328 -0.193633
# 7  0.095295 -0.195495  0.003099  1.345101
# 8 -0.707322  0.726656 -0.534248  0.679665
# 9 -1.375763 -0.884168 -0.360246  1.792734

# %%
plt.bar(df2['a'],df2['b'])
plt.title('Random Number Graphs Generator')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()
